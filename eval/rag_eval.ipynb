# %% [markdown]
# # RAG Answer Evaluation (Module 4)
#
# Goal: evaluate final answer quality with LLM-as-a-judge across multiple prompts
# and/or models. Report which prompt/model wins and the cost.
#
# TODO:
# 1. Run rag() on the ground-truth questions.
# 2. Use an LLM judge to score answers (RELEVANT / PARTLY / NON_RELEVANT).
# 3. Compare at least 2 prompts or 2 models.
# 4. Summarize results in docs/evaluation.md.

# %%
# TODO: implement LLM-as-a-judge evaluation here
